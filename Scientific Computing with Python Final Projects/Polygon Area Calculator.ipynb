# %% [markdown]
# Code Writer: Valf2K21 (fourth project)
#
# Project #4 in Scientific Computing with Python: Polygon Area Calculator
#
# Date Started: July 30, 2022
#
# Date Finished: July 31, 2022 (2 days)
#
# Task:
# 1. create a Rectangle main class initialized with width and height attributes, and must have the following methods:
#     - set_width
#     - set_height
#     - get_area - returns calculated area using the formula (width * height)
#     - get_perimeter - returns calculated perimeter using the formula (2 * width + 2 * height)
#     - get_diagonal - returns calculated diagonal using the formula ((width ** 2 + height ** 2) ** .5)
#     - get_picture - returns a string representing the shapes using lines of '*'; the number of lines should be equal to the height and the number of '*' in each line should be equal to the width; if the width or height is larger than 50, return the string 'Too big for picture.'
#     - get_amount_inside - takes another shape (square or rectangle) as an argument then returns the number of times the passed in shape could fit inside the shape with no rotations; for instance, a rectangle with a width of 4 and a height of 8 could fit in two squares with sides of 4
#     - additionally, if an instance of a Rectangle is represented as a string, it should look like: Rectangle(width = 5, height = 10)
# 2. create a Square sub class that will inherit all methods of Rectangle main class, and a single side length is passed as an attribute; in addition, it must have the following methods:
#     - __init__ - will store the side length in both the width and height attributes from the Rectangle main class
#     - set_side - if an instance of a Square is represented as a string, it should look like: Square(side = 9)
#     - additionally, the set_width and set_height methods on the Square class should set both the width and height

# %%
# a rectangle main class that has seven methods
class Rectangle:
    # use init function to make variables that objects can use independently
    def __init__(self, wdt, hgt):
        self.wdt = wdt
        self.hgt = hgt

    # a set_width method that sets the user-given width
    def set_width(self, wdt):
        self.wdt = wdt
        print('Rectangle(width = ' + str(self.wdt) + ', height = ' + str(self.hgt) + ')')

    # a set_width method that sets the user-given width
    def set_height(self, hgt):
        self.hgt = hgt
        print('Rectangle(width = ' + str(self.wdt) + ', height = ' + str(self.hgt) + ')')

    # a get_area method that calculates area
    def get_area(self):
        self.area = self.wdt * self.hgt
        print(self.area)

    # a get_perimeter method that calculates perimeter
    def get_perimeter(self):
        self.peri = (2 * self.wdt) + (2 * self.hgt)
        print(self.peri)

    # a get_diagonal method that calculates diagonal
    def get_diagonal(self):
        self.diag = ((self.wdt ** 2) + (self.hgt ** 2)) ** .5
        print(self.diag)

    # a get_picture method that prints the shape using *'s
    def get_picture(self):
        line = ''
        nW = 0
        nH = 0

        # print error message if shape is too big
        if(self.wdt > 50 or self.hgt > 50):
            print('Too big for picture.')

        else:
            while nH < self.hgt:
                while nW < self.wdt:
                    line = line + '*'
                    nW = nW + 1
                print(line)
                nH = nH + 1

    # a get_amount_inside method that calculates amount of shapes placeable inside another shape
    def get_amount_inside(self, shp):
        # set shape width and height depending on the shape to use to count
        if(shp == 'rectangle'):
            shpWdt = rectangle.wdt
            shpHgt = rectangle.hgt

        elif(shp == 'square'):
            shpWdt = square.wdt
            shpHgt = square.hgt

        # check if shape width and height is smaller than self width and height, then calculate
        if(shpWdt <= self.wdt):
            calcWdt = self.wdt // shpWdt

        else:
            calcWdt = None

        if(shpHgt <= self.hgt):
            calcHgt = self.hgt // shpHgt

        else:
            calcHgt = None

        # calculate answer then print it
        if(calcWdt != None or calcHgt != None):
            answer = calcWdt * calcHgt
            print(answer)

# a square sub class that will inherit rectangle's methods, and have unique methods of its own
class Square(Rectangle):
    # use init function to make variables that objects can use independently
    def __init__(self, sd):
        self.wdt = sd
        self.hgt = sd

    # a set_side method that sets the user-given side
    def set_side(self, sd):
        self.wdt = sd
        self.hgt = sd

    # a set_width method that sets the user-given width
    def set_width(self, sd):
        self.wdt = sd
        self.hgt = sd
        print('Square(side = ' + str(self.wdt) + ')')

    # a set_width method that sets the user-given width
    def set_height(self, sd):
        self.wdt = sd
        self.hgt = sd
        print('Square(side = ' + str(self.wdt) + ')')

# %%
# construct shape objects and store them in their respective variables
rectangle = Rectangle(16, 8)
square = Square(4)

# while-loop to keep the program running
while True:
    # ask the user for shape to modify
    chosenShape = input('Enter shape to modify (rectangle / square / exit): ')

    # exit program if user says so
    if(chosenShape == 'exit'):
        break

    # ask the user for instructions
    chosenOper = input('Enter operation to set/get (width / height / area / perimeter / diagonal / picture / amount inside / exit): ')

    # ask the user for new width if set width is chosen
    if(chosenOper == 'width'):
        width = int(input('Enter new width: '))

        if(chosenShape == 'rectangle'):
            rectangle.set_width(width)

        elif(chosenShape == 'square'):
            square.set_width(width)

    # ask the user for new height if set height is chosen
    elif(chosenOper == 'height'):
        height = int(input('Enter new height: '))

        if(chosenShape == 'rectangle'):
            rectangle.set_height(height)

        elif(chosenShape == 'square'):
            square.set_height(height)

    # calculate area if get area is chosen
    elif(chosenOper == 'area'):
        if(chosenShape == 'rectangle'):
            rectangle.get_area()

        elif(chosenShape == 'square'):
            square.get_area()

    # calculate perimeter if get perimeter is chosen
    elif(chosenOper == 'perimeter'):
        if(chosenShape == 'rectangle'):
            rectangle.get_perimeter()

        elif(chosenShape == 'square'):
            square.get_perimeter()

    # calculate diagonal if get diagonal is chosen
    elif(chosenOper == 'diagonal'):
        if(chosenShape == 'rectangle'):
            rectangle.get_diagonal()

        elif(chosenShape == 'square'):
            square.get_diagonal()

    # print picture if get picture is chosen
    elif(chosenOper == 'picture'):
        if(chosenShape == 'rectangle'):
            rectangle.get_picture()

        elif(chosenShape == 'square'):
            square.get_picture()

    # calculate amounts inside if get amount inside is chosen
    elif(chosenOper == 'amount inside'):
        if(chosenShape == 'rectangle'):
            shape = 'square'
            rectangle.get_amount_inside(shape)

        elif(chosenShape == 'square'):
            shape = 'rectangle'
            square.get_amount_inside(shape)
